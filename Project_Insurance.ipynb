# %% [markdown]
# <a href="https://colab.research.google.com/github/aayush081193/Data-Science/blob/main/Project_Insurance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Step 1 - Gathering data

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("/content/insurance.csv")

# %%
data.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
data['sex']=data['sex'].apply({'female':1,'male':0}.get)

# %%
data['smoker']=data['smoker'].apply({'yes':1,'no':0}.get)
data['region']=data['region'].apply({'southeast':1,'southwest':2,'northeast':3,'northwest':4}.get)

# %%
data.head()
# Out:
#    age  sex   bmi  children  smoker  region  expenses
# 0   19    1  27.9         0       1       2  16884.92
# 1   18    0  33.8         1       0       1   1725.55
# 2   28    0  33.0         3       0       1   4449.46
# 3   33    0  22.7         0       0       4  21984.47
# 4   32    0  28.9         0       0       4   3866.86

# %%
x=data[['age','sex','bmi','children','smoker','region']]
y=data['expenses']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8)

# %%
from sklearn.linear_model import LinearRegression
regression=LinearRegression()

# %%
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regression.predict(x_test)

# %%
print(y_pred)
# Out:
# [ 2.96599967e+04  1.28780614e+04  5.84580555e+03  1.41909149e+04
#   3.86693909e+03  1.31671921e+04  5.29631609e+03  1.03654299e+04
#   1.28725617e+04  1.06443063e+04  4.19104850e+03  9.35992669e+03
#   4.57283912e+03  4.09651523e+03  1.28277625e+04  8.81244348e+03
#   6.49422518e+03  1.44132023e+04  1.11460361e+03  2.48638647e+03
#   7.25319886e+03  2.06514925e+02  7.02412320e+03  6.81564691e+03
#   6.19502728e+03  1.18948776e+04  6.07353781e+03  3.51217996e+03
#   2.69615838e+01  1.57367685e+04  4.57549836e+03  2.75439958e+04
#   7.04741904e+03  3.06958718e+04  9.76590159e+03 -8.92950431e+01
#   1.41537734e+04  2.61050035e+04  6.98909517e+03  1.30372950e+04
#   2.83670939e+04  2.97153955e+04  6.64174502e+03  6.83948200e+03
#   7.73221043e+03  7.51566286e+03  2.36012707e+03  8.13938196e+03
#   7.13555198e+03  6.20270485e+03  3.49483801e+04  1.08344586e+04
#   2.85791117e+04  1.77571306e+04  1.39559436e+04  1.01490540e+04
# ...

# %%
regression.score(x,y)
# Out:
# 0.7500581240022911
